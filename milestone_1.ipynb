# %%
import string

from matplotlib import pyplot as plt
# %matplotlib inline

from data.generate_data import generate_train_data
from data.bounding_box_converter import read_dataset_csv, show_samples


char_list = list(string.ascii_letters) # we define the characters we want to detect/classify
char_list.extend(list(string.digits))
# Out:
# Using TensorFlow backend.

# %% [markdown]
# First we want to train our model on simple character images. We made an image generator for this purpose.

# %%
plt.rcParams['figure.dpi'] = 200 # bigger image
n_pictures = 5
data_generator = generate_train_data(batch_size = n_pictures, char_list=char_list, # we create the generator 
                                     font_list=["arial"], size_interval=(50, 200)) # that generates (image, label) tuples
images, chars = next(data_generator)
fig, axes = plt.subplots(1, n_pictures)
for i, ax in enumerate(axes):
    ax.imshow(images[i])
    
fig.show()
# Out:
# C:\Program Files\Python35\lib\site-packages\matplotlib\figure.py:403: UserWarning: matplotlib is currently using a non-GUI backend, so cannot show the figure
#   "matplotlib is currently using a non-GUI backend, "

# %% [markdown]
# We read that models that are trained on generated data are more accurate if word instances are placed in natural scene images, while taking into account the scene layout. So we downloaded the SynthText dataset, that is synthetically generated. We had to convert the bounding boxes of the characters since they were general quadrangles. The converted bounding boxes are rectangles rotated by an angle. White quadrangles are the original and red rectangles are the converted ones.

# %%
    plt.rcParams['figure.dpi'] = 300 # bigger image
    dataset = read_dataset_csv()
    show_samples(dataset)
# Out:
# data/SynthText\8\ballet_106_0.jpg
# data/SynthText\8\ballet_107_1.jpg
# data/SynthText\8\ballet_108_0.jpg
# data/SynthText\8\ballet_11_0.jpg
# data/SynthText\8\ballet_110_0.jpg
# data/SynthText\8\ballet_112_0.jpg
